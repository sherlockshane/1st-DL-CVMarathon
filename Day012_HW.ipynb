# ...

# %% [markdown]
# ### ② 如果想要依照類別分類，怎麼儲存會比較好？

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ettoday.net/news/news-list.htm'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find(class_="part_list_2").find_all('h3'):
    print(d.find(class_="date").text, d.find_all('a')[-1].text)
    print(d.find_all('em')[-1].text)
# Out:
# 2020/09/02 00:08 獨／大家都在找你！還拿留言給我看　高雄少女親曝「保全界李宗瑞」囚66小時
# 社會
# 2020/09/02 00:06 《小魔女DoReMI》聯名服飾喚起妳的童年　還有小花款象牙白仙氣逼人
# 時尚
# 2020/09/02 00:03 網傳「深綠色蔬菜」傷腎　食藥署點出高血鉀、腎結石真正風險
# 健康
# 2020/09/02 00:01 北市推「線上繳學費系統」　綁定悠遊付每月享300元回饋
# 政治
# 2020/09/01 23:56 89歲亞裔阿嬤遭「掌摑＋放火燒背」　吳彥祖氣炸懸賞44萬找兇手
# 影劇
# 2020/09/01 23:50 印軍邊界揮舞「雪山獅子旗」瘋傳　英媒：印軍佔領關鍵高地
# 軍武
# 2020/09/01 23:50 12月2日再報到！學運女神周庭獲續保　盼平安渡過24歲生日
# 大陸
# 2020/09/01 23:49 捷克議長訪台將「付出代價」　德外長警告王毅：威脅不適合這裡
# 國際
# 2020/09/01 23:43 開放瘦肉精美豬換取FTA門票？醫：當執政當局的養豬支持者很辛苦
# 生活
# 2020/09/01 23:42 痛失好友三浦春馬…佐藤健神隱近2月首度開直播！　短髮消瘦笑了
# 影劇
# 2020/09/01 23:40 12星座9月運勢大公開！　天秤「桃花運超旺」有機會發展新戀情
# 影劇
# 2020/09/01 23:32 新北八里區農會推單顆「平安柚」　中元普渡應景有拜有保佑
# 地方
# 2020/09/01 23:32 《粽邪2》在「大園空難停屍間」取景！女主角通靈一半「動了」嚇哭
# 影劇
# 2020/09/01 23:22 中職／張進德左大腿拉傷　洪總：要去醫院檢查
# 體育
# 2020/09/01 23:19 每天咀嚼9分鐘可防失智　陽明大學牙醫學院公佈「健口操」
# 健康
# 2020/09/01 23:12 中職／威拉諾不保　曾豪駒考慮拉尼寇力上一軍
# 體育
# 2020/09/01 23:04 中職／桃猿牛棚缺左投　陽耀勳：下次贏球登板才特別
# 體育
# 2020/09/01 22:51 花蓮膠筏遭浪襲翻覆！2船員依附膠筏漂流　海巡偕漁民救上岸
# 地方
# ...

# %% [markdown]
# ### ③ 哪一個類別的文章最多

# %%
news_dic = {}

for d in soup.find(class_="part_list_2").find_all('h3'):
    catalog = d.find(class_="tag").text
    title = d.find('a').text
    
    if catalog not in news_dic.keys():
        news_dic.update({catalog : []})
   
    news_dic[catalog].append(title)
    

max_len_catalog = '影劇'
max_len = len(news_dic['影劇'])

max_dic = {}

for key in news_dic.keys():
    if len(news_dic[key]) > max_len and key != "影劇":
        max_len = len(news_dic[key])
        max_len_catalog = key

for key in news_dic.keys():
    if len(news_dic[key]) == max_len:
        max_dic.update({key : max_len})
        
max_dic
# Out:
# {'社會': 17, '影劇': 17}
